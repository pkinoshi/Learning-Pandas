# %% [markdown]
# ###### pruning- to reduce, especially by eliminating(remove) superfluous(not needed) matter.

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.0.1'

# %% [markdown]
# #### Indexing with boolean masks

# %% [markdown]
# ###### step 1: generate sequence of booleans<br>step 2: Use boolean sequence in [] or .loc[]

# %%
players = pd.read_csv('soccer.csv')

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %% [markdown]
# ##### What are the players that have a market value exceeding 40M?

# %%
players.market_value>40 #..... step1
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Name: market_value, Length: 465, dtype: bool

# %%
players[players.market_value>40] #......step2
# Out:
#                   name               club  age position  position_cat  \
# 0       Alexis Sanchez            Arsenal   28       LW             1
# 1           Mesut Ozil            Arsenal   28       AM             1
# 96         Eden Hazard            Chelsea   26       LW             1
# 97         Diego Costa            Chelsea   28       CF             1
# 108     N%27Golo Kante            Chelsea   26       DM             2
# 218  Philippe Coutinho          Liverpool   25       AM             1
# 244    Kevin De Bruyne    Manchester+City   26       AM             1
# 245      Sergio Aguero    Manchester+City   29       CF             1
# 246    Raheem Sterling    Manchester+City   22       LW             1
# 264      Romelu Lukaku  Manchester+United   24       CF             1
# 267         Paul Pogba  Manchester+United   24       CM             2
# 380          Dele Alli          Tottenham   21       CM             2
# ...

# %%
players[players.market_value>40].shape[0]
# Out:
# 13

# %%
#OR
val = players.market_value>40

# %%
players[val].shape[0]
# Out:
# 13

# %% [markdown]
# 13 players have market value greater than 40M

# %% [markdown]
# #### More Approaches To Boolean Masking

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
players.age<25
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460     True
# 461     True
# 462     True
# 463     True
# 464    False
# Name: age, Length: 465, dtype: bool

# %%
players[players.age<25]
# Out:
#                         name      club  age position  position_cat  \
# 5            Hector Bellerin   Arsenal   22       RB             3
# 9                 Alex Iwobi   Arsenal   21       LW             1
# 10              Granit Xhaka   Arsenal   24       DM             2
# 11              Granit Xhaka   Arsenal   24       DM             2
# 12   Alex Oxlade-Chamberlain   Arsenal   23       RM             2
# ..                       ...       ...  ...      ...           ...
# 444           Manuel Lanzini  West+Ham   24       AM             1
# 460      Edimilson Fernandes  West+Ham   21       CM             2
# 461           Arthur Masuaku  West+Ham   23       LB             3
# 462                Sam Byram  West+Ham   23       RB             3
# 463          Ashley Fletcher  West+Ham   21       CF             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 5            30.0        1675        6.0  13.70%         119       2
# ...

# %%
players[players.age<=25]
# Out:
#                     name      club  age position  position_cat  market_value  \
# 5        Hector Bellerin   Arsenal   22       RB             3          30.0
# 8       Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 9             Alex Iwobi   Arsenal   21       LW             1          10.0
# 10          Granit Xhaka   Arsenal   24       DM             2          35.0
# 11          Granit Xhaka   Arsenal   24       DM             2          35.0
# ..                   ...       ...  ...      ...           ...           ...
# 456         Pedro Obiang  West+Ham   25       CM             2           9.0
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
#
# ...

# %%
players.loc[players.age<=25]
# Out:
#                     name      club  age position  position_cat  market_value  \
# 5        Hector Bellerin   Arsenal   22       RB             3          30.0
# 8       Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 9             Alex Iwobi   Arsenal   21       LW             1          10.0
# 10          Granit Xhaka   Arsenal   24       DM             2          35.0
# 11          Granit Xhaka   Arsenal   24       DM             2          35.0
# ..                   ...       ...  ...      ...           ...           ...
# 456         Pedro Obiang  West+Ham   25       CM             2           9.0
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
#
# ...

# %%
players.loc[players.age.le(25)]
# Out:
#                     name      club  age position  position_cat  market_value  \
# 5        Hector Bellerin   Arsenal   22       RB             3          30.0
# 8       Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 9             Alex Iwobi   Arsenal   21       LW             1          10.0
# 10          Granit Xhaka   Arsenal   24       DM             2          35.0
# 11          Granit Xhaka   Arsenal   24       DM             2          35.0
# ..                   ...       ...  ...      ...           ...           ...
# 456         Pedro Obiang  West+Ham   25       CM             2           9.0
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
#
# ...

# %%
players.loc[players.age<=25].equals(players.loc[players.age.le(25)])
# Out:
# True

# %% [markdown]
# ##### Binary Operations with booleans

# %%
#  Binary OR -> | Always False unless there's a True expression

# %%
True | False
# Out:
# True

# %%
True | True
# Out:
# True

# %%
False | True
# Out:
# True

# %%
False | False
# Out:
# False

# %%
# Binary AND -> & Always True unless there's a False expression

# %%
True & False
# Out:
# False

# %%
True & True
# Out:
# True

# %%
False & True
# Out:
# False

# %%
False & False
# Out:
# False

# %%
f= pd.Series(False)

# %%
t = pd.Series(True)

# %%
t & f
# Out:
# 0    False
# dtype: bool

# %%
t | f
# Out:
# 0    True
# dtype: bool

# %%
t = pd.Series([True if i%2==0 else False for i in range(10)])

# %%
f = pd.Series([False for i in range(10)])

# %%
t
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8     True
# 9    False
# dtype: bool

# %%
f
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
t & f
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
t | f
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8     True
# 9    False
# dtype: bool

# %%
f = pd.Series(data=[False, True, True], index=['c','b','a'])

# %%
t = pd.Series(data=[True,False,False], index=['a','b','c'])

# %%
t
# Out:
# a     True
# b    False
# c    False
# dtype: bool

# %%
f
# Out:
# c    False
# b     True
# a     True
# dtype: bool

# %%
t|f
# Out:
# a     True
# b     True
# c    False
# dtype: bool

# %%
t&f
# Out:
# a     True
# b    False
# c    False
# dtype: bool

# %% [markdown]
# ##### XOR And Complement Binary Operations

# %%
#Binary XOR -> ^ inputs are different to give True
                #inputs are the same to give False

# %%
True ^ True
# Out:
# False

# %%
True ^ False
# Out:
# True

# %%
False ^ True
# Out:
# True

# %%
False ^ False
# Out:
# False

# %%
True^(False|False&True) | False
# Out:
# True

# %%
#Two's Complement -> ~ tilda(-) negates

# %%
~False
# Out:
# -1

# %%
~True
# Out:
# -2

# %%
t = pd.Series([True,False,False])

# %%
t
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %% [markdown]
# #### Combining Conditions

# %%
#Select all the left backs -> LB

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
players.position == 'LB'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461     True
# 462    False
# 463    False
# 464    False
# Name: position, Length: 465, dtype: bool

# %%
players[players.position=='LB']
# Out:
#                       name               club  age position  position_cat  \
# 7            Nacho Monreal            Arsenal   31       LB             3
# 18            Kieran Gibbs            Arsenal   27       LB             3
# 29          Sead Kolasinac            Arsenal   24       LB             3
# 34         Charlie Daniels        Bournemouth   30       LB             3
# 54              Brad Smith        Bournemouth   23       LB             3
# 62             Gaetan Bong  Brighton+and+Hove   29       LB             3
# 65          Markus Suttner  Brighton+and+Hove   30       LB             3
# 82            Stephen Ward            Burnley   31       LB             3
# 99   Marcos Alonso Mendoza            Chelsea   26       LB             3
# 112                 Kenedy            Chelsea   21       LB             3
# 119    Patrick van Aanholt     Crystal+Palace   26       LB             3
# 128        Jeffrey Schlupp     Crystal+Palace   24       LB             3
# ...

# %%
players[players.position=='LB'].shape[0]
# Out:
# 35

# %%
#all left backs who are age 25 or younger

# %%
players[players.age <= 25]
# Out:
#                     name      club  age position  position_cat  market_value  \
# 5        Hector Bellerin   Arsenal   22       RB             3          30.0
# 8       Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 9             Alex Iwobi   Arsenal   21       LW             1          10.0
# 10          Granit Xhaka   Arsenal   24       DM             2          35.0
# 11          Granit Xhaka   Arsenal   24       DM             2          35.0
# ..                   ...       ...  ...      ...           ...           ...
# 456         Pedro Obiang  West+Ham   25       CM             2           9.0
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
#
# ...

# %%
players[players.age <= 25].shape[0]
# Out:
# 172

# %%
players[(players.position=='LB') & (players.age<=25)]
# Out:
#                  name               club  age position  position_cat  \
# 29     Sead Kolasinac            Arsenal   24       LB             3
# 54         Brad Smith        Bournemouth   23       LB             3
# 112            Kenedy            Chelsea   21       LB             3
# 128   Jeffrey Schlupp     Crystal+Palace   24       LB             3
# 212      Ben Chilwell     Leicester+City   20       LB             3
# 236    Alberto Moreno          Liverpool   25       LB             3
# 281         Luke Shaw  Manchester+United   22       LB             3
# 294      Paul Dummett   Newcastle+United   25       LB             3
# 298  Massadio Haidara   Newcastle+United   24       LB             3
# 328      Matt Targett        Southampton   21       LB             3
# 354        Josh Tymon         Stoke+City   18       LB             3
# 369  Stephen Kingsley            Swansea   22       LB             3
# 389        Ben Davies          Tottenham   24       LB             3
# ...

# %%
players[(players.position=='LB') & (players.age<=25)].shape[0]
# Out:
# 14

# %%
#3.conditions: left backs, 25 or younger, market value 10M+

# %%
players[(players.position=='LB') & 
        (players.age<=25) &
        (players.market_value>=10)
       ]
# Out:
#                name               club  age position  position_cat  \
# 29   Sead Kolasinac            Arsenal   24       LB             3
# 236  Alberto Moreno          Liverpool   25       LB             3
# 281       Luke Shaw  Manchester+United   22       LB             3
# 389      Ben Davies          Tottenham   24       LB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 29           15.0         618        6.0   6.90%           0       2
# 236          10.0         397        4.5   0.30%           8       2
# 281          20.0         947        5.0   0.40%          45       1
# 389          12.0         396        5.5   1.80%          90       2
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 29       Bosnia            1        2        1         1            0
# 236       Spain            0        3       10         1            0
# 281     England            0        2       12         1            0
# ...

# %%
#4.conditions: left backs, 25 or younger, market value 10M+, and not from Arsenal or Tottenham

# %%
players[(players.position=='LB') & 
        (players.age<=25) &
        (players.market_value>=10) &
        ~(players.club.isin(['Arsenal', 'Tottenham']))
       ]
# Out:
#                name               club  age position  position_cat  \
# 236  Alberto Moreno          Liverpool   25       LB             3
# 281       Luke Shaw  Manchester+United   22       LB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 236          10.0         397        4.5   0.30%           8       2
# 281          20.0         947        5.0   0.40%          45       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 236       Spain            0        3       10         1            0
# 281     England            0        2       12         1            0

# %%
players[(players.position=='LB') |
        (players.age<=25) ^
        (players.market_value>=10) &
        ~(players.club.isin(['Arsenal', 'Tottenham']))
       ]
# Out:
#                     name      club  age position  position_cat  market_value  \
# 5        Hector Bellerin   Arsenal   22       RB             3          30.0
# 7          Nacho Monreal   Arsenal   31       LB             3          13.0
# 8       Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 9             Alex Iwobi   Arsenal   21       LW             1          10.0
# 10          Granit Xhaka   Arsenal   24       DM             2          35.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %% [markdown]
# #### Conditions As Variables

# %%
players[(players.position=='LB') & 
        (players.age<=25) &
        (players.market_value>=10) &
        ~(players.club.isin(['Arsenal', 'Tottenham']))
       ]
# Out:
#                name               club  age position  position_cat  \
# 236  Alberto Moreno          Liverpool   25       LB             3
# 281       Luke Shaw  Manchester+United   22       LB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 236          10.0         397        4.5   0.30%           8       2
# 281          20.0         947        5.0   0.40%          45       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 236       Spain            0        3       10         1            0
# 281     England            0        2       12         1            0

# %%
#new target: Arsenal rightbacks and chelsea goalkeepers

# %%
players[(players.club=='Arsenal') & (players.position=='RB')]
# Out:
#                name     club  age position  position_cat  market_value  \
# 5   Hector Bellerin  Arsenal   22       RB             3          30.0
# 27   Carl Jenkinson  Arsenal   25       RB             3           5.0
#
#     page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 5         1675        6.0  13.70%         119       2       Spain
# 27         561        4.5   0.40%           2       1     England
#
#     new_foreign  age_cat  club_id  big_club  new_signing
# 5             0        2        1         1            0
# 27            0        3        1         1            0

# %%
arsenal_and_RB = (players.club=='Arsenal') & (players.position=='RB')

# %%
chelsea_and_GK = (players.club=='Chelsea') & (players.position=='GK')

# %%
players[arsenal_and_RB | chelsea_and_GK]
# Out:
#                  name     club  age position  position_cat  market_value  \
# 5     Hector Bellerin  Arsenal   22       RB             3          30.0
# 27     Carl Jenkinson  Arsenal   25       RB             3           5.0
# 102  Thibaut Courtois  Chelsea   25       GK             4          40.0
# 109   Willy Caballero  Chelsea   35       GK             4           1.5
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 5          1675        6.0  13.70%         119       2       Spain
# 27          561        4.5   0.40%           2       1     England
# 102        1260        5.5  18.50%         141       2     Belgium
# 109         542        5.0   0.20%          64       3   Argentina
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 5              0        2        1         1            0
# 27             0        3        1         1            0
# 102            0        3        5         1            0
# ...

# %% [markdown]
# #### Skill Challenge

# %%
players.nationality=='England'
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 460    False
# 461    False
# 462     True
# 463     True
# 464    False
# Name: nationality, Length: 465, dtype: bool

# %%
eng_nationality = players.nationality=='England'

# %%
players[players.nationality=='England'].shape[0]
# Out:
# 158

# %%
average = players.market_value.mean()

# %%
twice_mvalue = 2*average

# %%
twice_mvalue
# Out:
# 22.251298701298698

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
mvalue = players.market_value

# %%
views_and_signing = (players.page_views>4000) | (players.new_signing==1 )

# %%
views_and_signing
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 460     True
# 461     True
# 462    False
# 463     True
# 464    False
# Length: 465, dtype: bool

# %%
players[(eng_nationality) & (mvalue>twice_mvalue) & (views_and_signing)]
# Out:
#             name             club  age position  position_cat  market_value  \
# 256  John Stones  Manchester+City   23       CB             3          35.0
# 380    Dele Alli        Tottenham   21       CM             2          45.0
# 381   Harry Kane        Tottenham   23       CF             1          60.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 256        1078        5.5   2.30%          59       1     England
# 380        4626        9.5  38.60%         225       1     England
# 381        4161       12.5  35.10%         224       1     England
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 256            0        2       11         1            1
# 380            0        1       17         1            0
# 381            0        2       17         1            0

# %% [markdown]
# #### 2d Indexing

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
#Chelsea players and 23 years old or younger

# %%
chelsea_23under = (players.club=='Chelsea') & (players.age.le(23))

# %%
chelsea_23under
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Length: 465, dtype: bool

# %%
players.loc[chelsea_23under]
# Out:
#                  name     club  age position  position_cat  market_value  \
# 110   Michy Batshuayi  Chelsea   23       CF             1          25.0
# 111        Kurt Zouma  Chelsea   22       CB             3          15.0
# 112            Kenedy  Chelsea   21       LB             3           7.0
# 115  Tiemoue Bakayoko  Chelsea   22       DM             2          16.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 110        1162        8.5   1.60%          48       2     Belgium
# 111         723        5.5   0.80%          15       2      France
# 112         566        5.0   0.10%           3       3      Brazil
# 115        1011        5.0   1.60%           0       2      France
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 110            0        2        5         1            1
# 111            0        2        5         1            0
# 112            0        1        5         1            0
# ...

# %%
players.loc[chelsea_23under, ['name' ,'position', 'market_value', 'age']]
# Out:
#                  name position  market_value  age
# 110   Michy Batshuayi       CF          25.0   23
# 111        Kurt Zouma       CB          15.0   22
# 112            Kenedy       LB           7.0   21
# 115  Tiemoue Bakayoko       DM          16.0   22

# %%
#Select all columns that begins with 'p'

# %%
#using startswith

# %%
p_cols = players.columns.str.startswith('p')

# %%
p_cols
# Out:
# array([False, False, False,  True,  True, False,  True, False, False,
#        False, False, False, False, False, False, False, False])

# %%
players.loc[chelsea_23under, p_cols]
# Out:
#     position  position_cat  page_views
# 110       CF             1        1162
# 111       CB             3         723
# 112       LB             3         566
# 115       DM             2        1011

# %%
chelsea_23under.shape
# Out:
# (465,)

# %%
players.shape
# Out:
# (465, 17)

# %%
p_cols.shape
# Out:
# (17,)

# %%
# [] chaining

# %%
players[chelsea_23under]['position'] # this is slower
# Out:
# 110    CF
# 111    CB
# 112    LB
# 115    DM
# Name: position, dtype: object

# %%
players.loc[chelsea_23under, 'position'] # this is faster
# Out:
# 110    CF
# 111    CB
# 112    LB
# 115    DM
# Name: position, dtype: object

# %% [markdown]
# ##### Fancy Indexing with lookup()

# %%
players.lookup([450], ['age'])
# Out:
# array([30], dtype=int64)

# %%
players.loc[[0,132], ('name', 'market_value')] # fancy
# Out:
#                name  market_value
# 0    Alexis Sanchez          65.0
# 132  Connor Wickham           6.0

# %%
players.lookup([0,132], ('name', 'market_value'))
# Out:
# array(['Alexis Sanchez', 6.0], dtype=object)

# %%
players.lookup([0,132], ('market_value', 'name'))
# Out:
# array([65.0, 'Connor Wickham'], dtype=object)

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
names = ['Petr Cech', 'Mesut Ozil', 'Alexis Sanchez']
attributes = ['age', 'market_value', 'page_views']

# %%
players.set_index('name').lookup(names, attributes)
# Out:
# array([  35.,   50., 4329.])

# %% [markdown]
# #### Sorting by index or column

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
players.sort_values(by='market_value', ascending=False)
# Out:
#                     name               club  age position  position_cat  \
# 96           Eden Hazard            Chelsea   26       LW             1
# 267           Paul Pogba  Manchester+United   24       CM             2
# 0         Alexis Sanchez            Arsenal   28       LW             1
# 244      Kevin De Bruyne    Manchester+City   26       AM             1
# 245        Sergio Aguero    Manchester+City   29       CF             1
# ..                   ...                ...  ...      ...           ...
# 287  Joel Castro Pereira  Manchester+United   21       GK             4
# 113     Eduardo Carvalho            Chelsea   34       LW             1
# 30          Granit Xhaka            Arsenal   24      NaN             2
# 192         Steve Mounie       Huddersfield   22       CF             1
# 195    Kasper Schmeichel     Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# ...

# %%
players.index
# Out:
# RangeIndex(start=0, stop=465, step=1)

# %%
type(players.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
players.info(verbose= False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465 entries, 0 to 464
# Columns: 17 entries, name to new_signing
# dtypes: float64(2), int64(10), object(5)
# memory usage: 61.9+ KB

# %%
players.set_index('name', inplace=True)

# %%
players.head(4)
# Out:
#                    club  age position  position_cat  market_value  page_views  \
# name
# Alexis Sanchez  Arsenal   28       LW             1          65.0        4329
# Mesut Ozil      Arsenal   28       AM             1          50.0        4395
# Petr Cech       Arsenal   35       GK             4           7.0        1529
# Theo Walcott    Arsenal   28       RW             1          20.0        2393
#
#                 fpl_value fpl_sel  fpl_points  region     nationality  \
# name
# Alexis Sanchez       12.0  17.10%         264       3           Chile
# Mesut Ozil            9.5   5.60%         167       2         Germany
# Petr Cech             5.5   5.90%         134       2  Czech Republic
# Theo Walcott          7.5   1.50%         122       1         England
#
#                 new_foreign  age_cat  club_id  big_club  new_signing
# name
# Alexis Sanchez            0        4        1         1            0
# ...

# %%
players.sort_index().head(10)
# Out:
#                             club  age position  position_cat  market_value  \
# name
# Aaron Cresswell         West+Ham   27       LB             3          12.0
# Aaron Lennon             Everton   30       RW             1           5.0
# Aaron Mooy          Huddersfield   26       CM             2           5.0
# Aaron Ramsey             Arsenal   26       CM             2          35.0
# Abdoulaye Doucoure       Watford   24       CM             2           6.0
# Adam Federici        Bournemouth   32       GK             4           1.0
# Adam Lallana           Liverpool   29       AM             1          25.0
# Adam Smith           Bournemouth   26       RB             3           5.0
# Ademola Lookman          Everton   19       LW             1           5.0
# Adrian                  West+Ham   30       GK             4           8.0
#
#                     page_views  fpl_value fpl_sel  fpl_points  region  \
# name
# ...

# %%
players.sort_index(inplace=True)

# %%
players.head()
# Out:
#                             club  age position  position_cat  market_value  \
# name
# Aaron Cresswell         West+Ham   27       LB             3          12.0
# Aaron Lennon             Everton   30       RW             1           5.0
# Aaron Mooy          Huddersfield   26       CM             2           5.0
# Aaron Ramsey             Arsenal   26       CM             2          35.0
# Abdoulaye Doucoure       Watford   24       CM             2           6.0
#
#                     page_views  fpl_value fpl_sel  fpl_points  region  \
# name
# Aaron Cresswell            380        5.0   1.30%          60       1
# Aaron Lennon               504        5.5   0.20%          22       1
# Aaron Mooy                 588        5.5   2.50%           0       4
# Aaron Ramsey              1040        7.0   5.10%          56       1
# Abdoulaye Doucoure         124        5.0   0.00%          38       2
#
#                    nationality  new_foreign  age_cat  club_id  big_club  \
# ...

# %%
players.sort_index(axis=1)
# Out:
#                     age  age_cat  big_club            club  club_id  \
# name
# Aaron Cresswell      27        3         0        West+Ham       20
# Aaron Lennon         30        4         0         Everton        7
# Aaron Mooy           26        3         0    Huddersfield        8
# Aaron Ramsey         26        3         1         Arsenal        1
# Abdoulaye Doucoure   24        2         0         Watford       18
# ...                 ...      ...       ...             ...      ...
# Yohan Cabaye         31        4         0  Crystal+Palace        6
# YounÃ¨s Kaboul       31        4         0         Watford       18
# Ã‰tienne Capoue      29        4         0         Watford       18
# Ã€ngel Rangel        34        6         0         Swansea       16
# Åukasz FabiaÅ„ski   32        5         0         Swansea       16
#
#                     fpl_points fpl_sel  fpl_value  market_value nationality  \
# name
# ...

# %%
players.reset_index(inplace=True)

# %%
players.head()
# Out:
#                  name          club  age position  position_cat  market_value  \
# 0     Aaron Cresswell      West+Ham   27       LB             3          12.0
# 1        Aaron Lennon       Everton   30       RW             1           5.0
# 2          Aaron Mooy  Huddersfield   26       CM             2           5.0
# 3        Aaron Ramsey       Arsenal   26       CM             2          35.0
# 4  Abdoulaye Doucoure       Watford   24       CM             2           6.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0         380        5.0   1.30%          60       1     England            0
# 1         504        5.5   0.20%          22       1     England            0
# 2         588        5.5   2.50%           0       4   Australia            0
# 3        1040        7.0   5.10%          56       1       Wales            0
# 4         124        5.0   0.00%          38       2      France            0
#
# ...

# %% [markdown]
# ##### Sorting Vs Reordering

# %%
#reindex

# %%
players.iloc[:4, :4]
# Out:
#               name          club  age position
# 0  Aaron Cresswell      West+Ham   27       LB
# 1     Aaron Lennon       Everton   30       RW
# 2       Aaron Mooy  Huddersfield   26       CM
# 3     Aaron Ramsey       Arsenal   26       CM

# %%
players_lite = players.iloc[:4, :4]

# %%
#row order: 2,1 ,3, 0
#column order: age, name, position, club

# %%
players_lite.reindex(index=[2,1,3,0], columns=['age', 'name', 'position', 'club'])
# Out:
#    age             name position          club
# 2   26       Aaron Mooy       CM  Huddersfield
# 1   30     Aaron Lennon       RW       Everton
# 3   26     Aaron Ramsey       CM       Arsenal
# 0   27  Aaron Cresswell       LB      West+Ham

# %%
players.reindex(index=[2,1,3,0], columns=['age', 'name', 'position', 'club'])
# Out:
#    age             name position          club
# 2   26       Aaron Mooy       CM  Huddersfield
# 1   30     Aaron Lennon       RW       Everton
# 3   26     Aaron Ramsey       CM       Arsenal
# 0   27  Aaron Cresswell       LB      West+Ham

# %%
#get all the columns in alphabetical order

# %%
players.reindex(index=[2,1,3,0]).sort_index(axis=1)
# Out:
#    age  age_cat  big_club          club  club_id  fpl_points fpl_sel  \
# 2   26        3         0  Huddersfield        8           0   2.50%
# 1   30        4         0       Everton        7          22   0.20%
# 3   26        3         1       Arsenal        1          56   5.10%
# 0   27        3         0      West+Ham       20          60   1.30%
#
#    fpl_value  market_value             name nationality  new_foreign  \
# 2        5.5           5.0       Aaron Mooy   Australia            0
# 1        5.5           5.0     Aaron Lennon     England            0
# 3        7.0          35.0     Aaron Ramsey       Wales            0
# 0        5.0          12.0  Aaron Cresswell     England            0
#
#    new_signing  page_views position  position_cat  region
# 2            0         588       CM             2       4
# 1            0         504       RW             1       1
# 3            0        1040       CM             2       1
# ...

# %%
#OR
#players.reindex(index=[2,1,3,0], columns=[])

# %%
# how do we get a sorted list of column lables?

# %%
players.columns
# Out:
# Index(['name', 'club', 'age', 'position', 'position_cat', 'market_value',
#        'page_views', 'fpl_value', 'fpl_sel', 'fpl_points', 'region',
#        'nationality', 'new_foreign', 'age_cat', 'club_id', 'big_club',
#        'new_signing'],
#       dtype='object')

# %%
iter(players.columns)

# %%
sorted(players.columns)
# Out:
# ['age',
#  'age_cat',
#  'big_club',
#  'club',
#  'club_id',
#  'fpl_points',
#  'fpl_sel',
#  'fpl_value',
#  'market_value',
#  'name',
#  'nationality',
#  'new_foreign',
#  'new_signing',
#  'page_views',
#  'position',
#  'position_cat',
#  'region']

# %%
players.reindex(index=[2,1,3,0], columns=sorted(players.columns))
# Out:
#    age  age_cat  big_club          club  club_id  fpl_points fpl_sel  \
# 2   26        3         0  Huddersfield        8           0   2.50%
# 1   30        4         0       Everton        7          22   0.20%
# 3   26        3         1       Arsenal        1          56   5.10%
# 0   27        3         0      West+Ham       20          60   1.30%
#
#    fpl_value  market_value             name nationality  new_foreign  \
# 2        5.5           5.0       Aaron Mooy   Australia            0
# 1        5.5           5.0     Aaron Lennon     England            0
# 3        7.0          35.0     Aaron Ramsey       Wales            0
# 0        5.0          12.0  Aaron Cresswell     England            0
#
#    new_signing  page_views position  position_cat  region
# 2            0         588       CM             2       4
# 1            0         504       RW             1       1
# 3            0        1040       CM             2       1
# ...

# %%
players.reindex(index=[2,1,3,0], columns=sorted(players.columns)[:6])
# Out:
#    age  age_cat  big_club          club  club_id  fpl_points
# 2   26        3         0  Huddersfield        8           0
# 1   30        4         0       Everton        7          22
# 3   26        3         1       Arsenal        1          56
# 0   27        3         0      West+Ham       20          60

# %%
#Another way to sort columns

# %%
players.reindex(index=[2,1,3,0], columns=players.columns.sort_values())
# Out:
#    age  age_cat  big_club          club  club_id  fpl_points fpl_sel  \
# 2   26        3         0  Huddersfield        8           0   2.50%
# 1   30        4         0       Everton        7          22   0.20%
# 3   26        3         1       Arsenal        1          56   5.10%
# 0   27        3         0      West+Ham       20          60   1.30%
#
#    fpl_value  market_value             name nationality  new_foreign  \
# 2        5.5           5.0       Aaron Mooy   Australia            0
# 1        5.5           5.0     Aaron Lennon     England            0
# 3        7.0          35.0     Aaron Ramsey       Wales            0
# 0        5.0          12.0  Aaron Cresswell     England            0
#
#    new_signing  page_views position  position_cat  region
# 2            0         588       CM             2       4
# 1            0         504       RW             1       1
# 3            0        1040       CM             2       1
# ...

# %% [markdown]
# ##### Avoid Sorting like this

# %%
#anti-pattern

# %%
df = players.iloc[:6, :6]

# %%
df
# Out:
#                  name          club  age position  position_cat  market_value
# 0     Aaron Cresswell      West+Ham   27       LB             3          12.0
# 1        Aaron Lennon       Everton   30       RW             1           5.0
# 2          Aaron Mooy  Huddersfield   26       CM             2           5.0
# 3        Aaron Ramsey       Arsenal   26       CM             2          35.0
# 4  Abdoulaye Doucoure       Watford   24       CM             2           6.0
# 5       Adam Federici   Bournemouth   32       GK             4           1.0

# %%
df.swapaxes(1,0)
# Out:
#                             0             1             2             3  \
# name          Aaron Cresswell  Aaron Lennon    Aaron Mooy  Aaron Ramsey
# club                 West+Ham       Everton  Huddersfield       Arsenal
# age                        27            30            26            26
# position                   LB            RW            CM            CM
# position_cat                3             1             2             2
# market_value               12             5             5            35
#
#                                4              5
# name          Abdoulaye Doucoure  Adam Federici
# club                     Watford    Bournemouth
# age                           24             32
# position                      CM             GK
# position_cat                   2              4
# market_value                   6              1

# %%
df.T
# Out:
#                             0             1             2             3  \
# name          Aaron Cresswell  Aaron Lennon    Aaron Mooy  Aaron Ramsey
# club                 West+Ham       Everton  Huddersfield       Arsenal
# age                        27            30            26            26
# position                   LB            RW            CM            CM
# position_cat                3             1             2             2
# market_value               12             5             5            35
#
#                                4              5
# name          Abdoulaye Doucoure  Adam Federici
# club                     Watford    Bournemouth
# age                           24             32
# position                      CM             GK
# position_cat                   2              4
# market_value                   6              1

# %%
df.T.sort_index()
# Out:
#                             0             1             2             3  \
# age                        27            30            26            26
# club                 West+Ham       Everton  Huddersfield       Arsenal
# market_value               12             5             5            35
# name          Aaron Cresswell  Aaron Lennon    Aaron Mooy  Aaron Ramsey
# position                   LB            RW            CM            CM
# position_cat                3             1             2             2
#
#                                4              5
# age                           24             32
# club                     Watford    Bournemouth
# market_value                   6              1
# name          Abdoulaye Doucoure  Adam Federici
# position                      CM             GK
# position_cat                   2              4

# %%
df.T.sort_index().T
# Out:
#   age          club market_value                name position position_cat
# 0  27      West+Ham           12     Aaron Cresswell       LB            3
# 1  30       Everton            5        Aaron Lennon       RW            1
# 2  26  Huddersfield            5          Aaron Mooy       CM            2
# 3  26       Arsenal           35        Aaron Ramsey       CM            2
# 4  24       Watford            6  Abdoulaye Doucoure       CM            2
# 5  32   Bournemouth            1       Adam Federici       GK            4

# %%
df.sort_index(axis=1)
# Out:
#    age          club  market_value                name position  position_cat
# 0   27      West+Ham          12.0     Aaron Cresswell       LB             3
# 1   30       Everton           5.0        Aaron Lennon       RW             1
# 2   26  Huddersfield           5.0          Aaron Mooy       CM             2
# 3   26       Arsenal          35.0        Aaron Ramsey       CM             2
# 4   24       Watford           6.0  Abdoulaye Doucoure       CM             2
# 5   32   Bournemouth           1.0       Adam Federici       GK             4

# %% [markdown]
# #### Skill Challenge

# %%
#1. Sort the players in the dataframe by age in ascending order. Who is the youngest footballer in the EPL?

# %%
players.head()
# Out:
#                  name          club  age position  position_cat  market_value  \
# 0     Aaron Cresswell      West+Ham   27       LB             3          12.0
# 1        Aaron Lennon       Everton   30       RW             1           5.0
# 2          Aaron Mooy  Huddersfield   26       CM             2           5.0
# 3        Aaron Ramsey       Arsenal   26       CM             2          35.0
# 4  Abdoulaye Doucoure       Watford   24       CM             2           6.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0         380        5.0   1.30%          60       1     England            0
# 1         504        5.5   0.20%          22       1     England            0
# 2         588        5.5   2.50%           0       4   Australia            0
# 3        1040        7.0   5.10%          56       1       Wales            0
# 4         124        5.0   0.00%          38       2      France            0
#
# ...

# %%
players.sort_values(by='age', ascending=True)
# Out:
#                        name               club  age position  position_cat  \
# 53             Ben Woodburn          Liverpool   17       LW             1
# 217           Jonathan Leko          West+Brom   18       RW             1
# 434  Trent Alexander-Arnold          Liverpool   18       RB             3
# 229              Josh Tymon         Stoke+City   18       LB             3
# 45            Axel Tuanzebe  Manchester+United   19       CB             3
# ..                      ...                ...  ...      ...           ...
# 142            Gareth Barry            Everton   36       DM             2
# 90           Damien Delaney     Crystal+Palace   36       CB             3
# 38              Artur Boruc        Bournemouth   37       GK             4
# 143          Gareth McAuley          West+Brom   37       CB             3
# 232          Julian Speroni     Crystal+Palace   38       GK             4
#
# ...

# %%
players.sort_values(by='age', ascending=True).nsmallest(1, columns='age')
# Out:
#             name       club  age position  position_cat  market_value  \
# 53  Ben Woodburn  Liverpool   17       LW             1           1.5
#
#     page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 53        1241        4.5   0.10%           5       1       Wales
#
#     new_foreign  age_cat  club_id  big_club  new_signing
# 53            0        1       10         1            0

# %% [markdown]
# Ben Woodburn is the youngest player, age 17

# %%
#2.Set the club column as the index of the dataframe. Then sort the dataframe index in alphabetical order. Make sure these 
#   changes are applied to the underlying dataframe and carry over to the next question

# %%
players.set_index('club', inplace=True)

# %%
players.sort_index(axis=0, inplace=True)

# %%
players
# Out:
#                          name  age position  position_cat  market_value  \
# club
# Arsenal          David Ospina   28       GK             4           7.0
# Arsenal   Alexandre Lacazette   26       CF             1          40.0
# Arsenal        Alexis Sanchez   28       LW             1          65.0
# Arsenal     Laurent Koscielny   31       CB             3          22.0
# Arsenal            Mesut Ozil   28       AM             1          50.0
# ...                       ...  ...      ...           ...           ...
# West+Ham           Mark Noble   30       CM             2           7.0
# West+Ham      Michail Antonio   27       RW             1          18.0
# West+Ham     Robert Snodgrass   29       RW             1           8.0
# West+Ham      Ashley Fletcher   21       CF             1           1.0
# West+Ham      Aaron Cresswell   27       LB             3          12.0
#
#           page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# club
# ...

# %%
#3.Sort the dataframe values by club and market_value, where the club is alphabetical(Arsenal first) and the market value is in
#  descending order(within each team, the most valuable player first)

# %%
players.sort_values(by=['club', 'market_value'], ascending=(True, False))
# Out:
#                          name  age position  position_cat  market_value  \
# club
# Arsenal        Alexis Sanchez   28       LW             1          65.0
# Arsenal            Mesut Ozil   28       AM             1          50.0
# Arsenal   Alexandre Lacazette   26       CF             1          40.0
# Arsenal          Granit Xhaka   24       DM             2          35.0
# Arsenal          Granit Xhaka   24       DM             2          35.0
# ...                       ...  ...      ...           ...           ...
# West+Ham  Edimilson Fernandes   21       CM             2           5.0
# West+Ham            Sam Byram   23       RB             3           4.5
# West+Ham      Darren Randolph   30       GK             4           2.5
# West+Ham        James Collins   33       CB             3           2.0
# West+Ham      Ashley Fletcher   21       CF             1           1.0
#
#           page_views  fpl_value fpl_sel  fpl_points  region  nationality  \
# club
# ...

# %% [markdown]
# #### Identifyng Dupes

# %%
players.head()
# Out:
#                         name  age position  position_cat  market_value  \
# club
# Arsenal         David Ospina   28       GK             4           7.0
# Arsenal  Alexandre Lacazette   26       CF             1          40.0
# Arsenal       Alexis Sanchez   28       LW             1          65.0
# Arsenal    Laurent Koscielny   31       CB             3          22.0
# Arsenal           Mesut Ozil   28       AM             1          50.0
#
#          page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# club
# Arsenal         544        5.0   0.20%           2       3    Colombia
# Arsenal        1183       10.5  26.50%           0       2      France
# Arsenal        4329       12.0  17.10%         264       3       Chile
# Arsenal         912        6.0   0.70%         121       2      France
# Arsenal        4395        9.5   5.60%         167       2     Germany
#
#          new_foreign  age_cat  club_id  big_club  new_signing
# club
# ...

# %%
players.duplicated()
# Out:
# club
# Arsenal     False
# Arsenal     False
# Arsenal     False
# Arsenal     False
# Arsenal     False
#             ...
# West+Ham    False
# West+Ham    False
# West+Ham    False
# West+Ham    False
# West+Ham    False
# Length: 465, dtype: bool

# %%
players[players.duplicated()]
# Out:
#                             name  age position  position_cat  market_value  \
# club
# Arsenal             Granit Xhaka   24       DM             2          35.0
# Arsenal  Alex Oxlade-Chamberlain   23       RM             2          22.0
# Arsenal  Alex Oxlade-Chamberlain   23       RM             2          22.0
#
#          page_views  fpl_value fpl_sel  fpl_points  region  nationality  \
# club
# Arsenal        1815        5.5   2.00%          85       2  Switzerland
# Arsenal        1519        6.0   1.80%          83       1      England
# Arsenal        1519        6.0   1.80%          83       1      England
#
#          new_foreign  age_cat  club_id  big_club  new_signing
# club
# Arsenal            0        2        1         1            0
# Arsenal            0        2        1         1            0
# Arsenal            0        2        1         1            0

# %%
players.reset_index(inplace=True)

# %%
#the subset parameter

# %%
#unique -> club, position, market value

# %%
players.duplicated(subset=['club', 'position', 'market_value'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Length: 465, dtype: bool

# %%
players.loc[players.duplicated(subset=['club', 'position', 'market_value'])]
# Out:
#                   club                     name  age position  position_cat  \
# 14             Arsenal             Granit Xhaka   24       DM             2
# 17             Arsenal  Alex Oxlade-Chamberlain   23       RM             2
# 22             Arsenal            Danny Welbeck   26       CF             1
# 24             Arsenal  Alex Oxlade-Chamberlain   23       RM             2
# 30             Arsenal                Petr Cech   35       GK             4
# 46         Bournemouth             Tyrone Mings   24       CB             3
# 47         Bournemouth              Artur Boruc   37       GK             4
# 55         Bournemouth            Callum Wilson   25       CF             1
# 65   Brighton+and+Hove              Shane Duffy   25       CB             3
# 89             Burnley            Steven Defour   29       CM             2
# 178       Huddersfield           Dean Whitehead   35       CM             2
# ...

# %%
players.loc[players.duplicated(subset=['club', 'position', 'market_value'])].shape
# Out:
# (27, 17)

# %%
"""When dealing with duplicates, the first is the original by default unless the keep parameter is used"""
# Out:
# 'When dealing with duplicates, the first is the original by default unless the keep parameter is used'

# %%
players.loc[players.duplicated(subset=['club', 'age', 'position', 'market_value'], keep='first')].shape
# Out:
# (7, 17)

# %%
players.loc[players.duplicated(subset=['club', 'age', 'position', 'market_value'], keep='last')].shape
# Out:
# (7, 17)

# %%
players.loc[players.duplicated(subset=['club', 'age', 'position', 'market_value'], keep=False)].shape
# Out:
# (13, 17)

# %% [markdown]
# #### Removing Duplicates

# %%
players[players.duplicated()]
# Out:
#        club                     name  age position  position_cat  \
# 14  Arsenal             Granit Xhaka   24       DM             2
# 17  Arsenal  Alex Oxlade-Chamberlain   23       RM             2
# 24  Arsenal  Alex Oxlade-Chamberlain   23       RM             2
#
#     market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 14          35.0        1815        5.5   2.00%          85       2
# 17          22.0        1519        6.0   1.80%          83       1
# 24          22.0        1519        6.0   1.80%          83       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 14  Switzerland            0        2        1         1            0
# 17      England            0        2        1         1            0
# 24      England            0        2        1         1            0

# %%
players[players.duplicated(subset=None, keep='first')]
# Out:
#        club                     name  age position  position_cat  \
# 14  Arsenal             Granit Xhaka   24       DM             2
# 17  Arsenal  Alex Oxlade-Chamberlain   23       RM             2
# 24  Arsenal  Alex Oxlade-Chamberlain   23       RM             2
#
#     market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 14          35.0        1815        5.5   2.00%          85       2
# 17          22.0        1519        6.0   1.80%          83       1
# 24          22.0        1519        6.0   1.80%          83       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 14  Switzerland            0        2        1         1            0
# 17      England            0        2        1         1            0
# 24      England            0        2        1         1            0

# %%
players.market_value.mean()
# Out:
# 11.125649350649349

# %%
players.drop_duplicates(keep='first')
# Out:
#          club                 name  age position  position_cat  market_value  \
# 0     Arsenal         David Ospina   28       GK             4           7.0
# 1     Arsenal  Alexandre Lacazette   26       CF             1          40.0
# 2     Arsenal       Alexis Sanchez   28       LW             1          65.0
# 3     Arsenal    Laurent Koscielny   31       CB             3          22.0
# 4     Arsenal           Mesut Ozil   28       AM             1          50.0
# ..        ...                  ...  ...      ...           ...           ...
# 460  West+Ham           Mark Noble   30       CM             2           7.0
# 461  West+Ham      Michail Antonio   27       RW             1          18.0
# 462  West+Ham     Robert Snodgrass   29       RW             1           8.0
# 463  West+Ham      Ashley Fletcher   21       CF             1           1.0
# 464  West+Ham      Aaron Cresswell   27       LB             3          12.0
#
# ...

# %%
players.drop_duplicates(keep='first').market_value.mean()
# Out:
# 11.026252723311545

# %%
#NOTE: Duplicates are not necessarily bad

# %% [markdown]
# #### Removing DataFrame Rows

# %%
players[players.duplicated()]
# Out:
#        club                     name  age position  position_cat  \
# 14  Arsenal             Granit Xhaka   24       DM             2
# 17  Arsenal  Alex Oxlade-Chamberlain   23       RM             2
# 24  Arsenal  Alex Oxlade-Chamberlain   23       RM             2
#
#     market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 14          35.0        1815        5.5   2.00%          85       2
# 17          22.0        1519        6.0   1.80%          83       1
# 24          22.0        1519        6.0   1.80%          83       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 14  Switzerland            0        2        1         1            0
# 17      England            0        2        1         1            0
# 24      England            0        2        1         1            0

# %%
players = pd.read_csv('soccer.csv')

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
players[players.duplicated()]
# Out:
#                        name     club  age position  position_cat  \
# 11             Granit Xhaka  Arsenal   24       DM             2
# 13  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# 23  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
#
#     market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 11          35.0        1815        5.5   2.00%          85       2
# 13          22.0        1519        6.0   1.80%          83       1
# 23          22.0        1519        6.0   1.80%          83       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 11  Switzerland            0        2        1         1            0
# 13      England            0        2        1         1            0
# 23      England            0        2        1         1            0

# %%
players.drop(labels=11, axis=0)
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
players.drop(index=[23, 11])
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %% [markdown]
# #### Removing Columns

# %%
players.drop(columns=['club', 'position', 'market_value'])
# Out:
#                     name  age  position_cat  page_views  fpl_value fpl_sel  \
# 0         Alexis Sanchez   28             1        4329       12.0  17.10%
# 1             Mesut Ozil   28             1        4395        9.5   5.60%
# 2              Petr Cech   35             4        1529        5.5   5.90%
# 3           Theo Walcott   28             1        2393        7.5   1.50%
# 4      Laurent Koscielny   31             3         912        6.0   0.70%
# ..                   ...  ...           ...         ...        ...     ...
# 460  Edimilson Fernandes   21             2         288        4.5   0.40%
# 461       Arthur Masuaku   23             3         199        4.5   0.20%
# 462            Sam Byram   23             3         198        4.5   0.30%
# 463      Ashley Fletcher   21             1         412        4.5   5.90%
# 464         Diafra Sakho   27             1         214        5.5   0.10%
#
# ...

# %% [markdown]
# #### Alternative

# %%
# using reindex to remove rows and columns

# %%
players.reindex(index=[0, 1, 2])
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1      Mesut Ozil  Arsenal   28       AM             1          50.0
# 2       Petr Cech  Arsenal   35       GK             4           7.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0

# %%
unwanted_rows = [1,2,3,4]

# %%
players.reindex(index=set(players.index).difference(unwanted_rows))
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 5        Hector Bellerin   Arsenal   22       RB             3          30.0
# 6         Olivier Giroud   Arsenal   30       CF             1          22.0
# 7          Nacho Monreal   Arsenal   31       LB             3          13.0
# 8       Shkodran Mustafi   Arsenal   25       CB             3          30.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
unwanted_columns = ['name', 'position']

# %%
players.reindex(columns=set(players.columns).difference(unwanted_columns))
# Out:
#      big_club     nationality  fpl_points  club_id  new_foreign  fpl_value  \
# 0           1           Chile         264        1            0       12.0
# 1           1         Germany         167        1            0        9.5
# 2           1  Czech Republic         134        1            0        5.5
# 3           1         England         122        1            0        7.5
# 4           1          France         121        1            0        6.0
# ..        ...             ...         ...      ...          ...        ...
# 460         0     Switzerland          38       20            0        4.5
# 461         0        Congo DR          34       20            0        4.5
# 462         0         England          29       20            0        4.5
# 463         0         England          16       20            0        4.5
# 464         0         Senegal          12       20            0        5.5
#
# ...

# %% [markdown]
# #### Null Values in DFs

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
#series refresher

# %%
players.age
# Out:
# 0      28
# 1      28
# 2      35
# 3      28
# 4      31
#        ..
# 460    21
# 461    23
# 462    23
# 463    21
# 464    27
# Name: age, Length: 465, dtype: int64

# %%
ages = players.age

# %%
ages
# Out:
# 0      28
# 1      28
# 2      35
# 3      28
# 4      31
#        ..
# 460    21
# 461    23
# 462    23
# 463    21
# 464    27
# Name: age, Length: 465, dtype: int64

# %%
ages.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Name: age, Length: 465, dtype: bool

# %%
ages[ages.isna()]
# Out:
# Series([], Name: age, dtype: int64)

# %%
players.age.isna().sum()
# Out:
# 0

# %%
players.age.isna().isna().sum()
# Out:
# 0

# %%
#DataFrame

# %%
players.isna()
# Out:
#       name   club    age  position  position_cat  market_value  page_views  \
# 0    False  False  False     False         False         False       False
# 1    False  False  False     False         False         False       False
# 2    False  False  False     False         False         False       False
# 3    False  False  False     False         False         False       False
# 4    False  False  False     False         False         False       False
# ..     ...    ...    ...       ...           ...           ...         ...
# 460  False  False  False     False         False         False       False
# 461  False  False  False     False         False         False       False
# 462  False  False  False     False         False         False       False
# 463  False  False  False     False         False         False       False
# 464  False  False  False     False         False         False       False
#
# ...

# %%
#How many NAs are there in this dataframe?

# %%
#For DataFrame
np.count_nonzero(players.isna())
# Out:
# 4

# %%
# For Series
players.position.isna().sum()
# Out:
# 1

# %%
#which records have NA in this dataframe?

# %%
players.isna().values
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
players[players.isna().values]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30            NaN        1815        5.5   2.00%          85       2
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 30   Switzerland            0        2        1         1            0
# ...

# %%
players[players.isna().values].drop_duplicates()
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %% [markdown]
# #### Dropping And Filling DataFrame NAs

# %%
players.fillna('something meaningful').loc[[30,192,195]]
# Out:
#                   name            club  age              position  \
# 30        Granit Xhaka         Arsenal   24  something meaningful
# 192       Steve Mounie    Huddersfield   22                    CF
# 195  Kasper Schmeichel  Leicester+City   30                    GK
#
#      position_cat          market_value  page_views  fpl_value fpl_sel  \
# 30              2  something meaningful        1815        5.5   2.00%
# 192             1  something meaningful          56        6.0   0.60%
# 195             4  something meaningful        1601        5.0   2.40%
#
#      fpl_points  region  nationality  new_foreign  age_cat  club_id  big_club  \
# 30           85       2  Switzerland            0        2        1         1
# 192           0       2        Benin            0        2        8         0
# 195         109       2      Denmark            0        4        9         0
#
#      new_signing
# 30             0
# 192            0
# 195            0

# %%
players.iloc[20:30]
# Out:
#                        name     club  age position  position_cat  \
# 20            Danny Welbeck  Arsenal   26       CF             1
# 21              Rob Holding  Arsenal   21       CB             3
# 22           Mohamed Elneny  Arsenal   25       DM             2
# 23  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# 24              Lucas Perez  Arsenal   28       CF             1
# 25        Emiliano Martinez  Arsenal   24       GK             4
# 26             David Ospina  Arsenal   28       GK             4
# 27           Carl Jenkinson  Arsenal   25       RB             3
# 28          Per Mertesacker  Arsenal   32       CB             3
# 29           Sead Kolasinac  Arsenal   24       LB             3
#
#     market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 20          15.0        1521        7.5   0.50%          37       1
# 21           7.0         666        5.0   1.70%          32       1
# ...

# %%
players.index
# Out:
# RangeIndex(start=0, stop=465, step=1)

# %%
type(players.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
players.position.unique()
# Out:
# array(['LW', 'AM', 'GK', 'RW', 'CB', 'RB', 'CF', 'LB', 'DM', 'RM', 'CM',
#        nan, 'SS', 'LM'], dtype=object)

# %%
players.club.unique()[0]
# Out:
# 'Arsenal'

# %%
players.club.unique()[10]
# Out:
# 'Manchester+City'

# %%
players.fillna({'market_value':100, 'position':'RM'}).loc[[30, 192, 195]]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24       RM             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30          100.0        1815        5.5   2.00%          85       2
# 192         100.0          56        6.0   0.60%           0       2
# 195         100.0        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %%
players.fillna({'position':'wetin u dey play', 'market_value': 'Elo lowo ori e'}).loc[[30, 192, 195]]
# Out:
#                   name            club  age          position  position_cat  \
# 30        Granit Xhaka         Arsenal   24  wetin u dey play             2
# 192       Steve Mounie    Huddersfield   22                CF             1
# 195  Kasper Schmeichel  Leicester+City   30                GK             4
#
#        market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30   Elo lowo ori e        1815        5.5   2.00%          85       2
# 192  Elo lowo ori e          56        6.0   0.60%           0       2
# 195  Elo lowo ori e        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %%
#How about dropping nulls?

# %%
players.dropna()
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
#OR
players.dropna(axis=1, how='any').loc[[30, 192, 195]] #this drops the columns with na values
# Out:
#                   name            club  age  position_cat  page_views  \
# 30        Granit Xhaka         Arsenal   24             2        1815
# 192       Steve Mounie    Huddersfield   22             1          56
# 195  Kasper Schmeichel  Leicester+City   30             4        1601
#
#      fpl_value fpl_sel  fpl_points  region  nationality  new_foreign  age_cat  \
# 30         5.5   2.00%          85       2  Switzerland            0        2
# 192        6.0   0.60%           0       2        Benin            0        2
# 195        5.0   2.40%         109       2      Denmark            0        4
#
#      club_id  big_club  new_signing
# 30         1         1            0
# 192        8         0            0
# 195        9         0            0

# %%
players.dropna(axis=1, how='all').loc[[30, 192, 195]]# drops none of the columns because not all the values are NAs
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %%
#players.dropna(axis=0, how='any').loc[[30, 192, 195]]-this would give an error because the row has at least one NA

# %%
players.dropna(axis=0, how='all').loc[[30, 192, 195]]# this won't drop any row it does not contain NAs only
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %% [markdown]
# ##### Methods And Axes with fillna()

# %%
players[players.isna().values]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30            NaN        1815        5.5   2.00%          85       2
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 30   Switzerland            0        2        1         1            0
# ...

# %%
players[players.isna().values].drop_duplicates()
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %%
players.fillna(method='ffill').loc[[30, 192, 195]]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24       LB             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30           15.0        1815        5.5   2.00%          85       2
# 192           3.0          56        6.0   0.60%           0       2
# 195          30.0        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %%
players.market_value.loc[29]
# Out:
# 15.0

# %%
players.fillna(method='bfill').loc[[30, 192, 195]] # fills across rows
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24       CF             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30           40.0        1815        5.5   2.00%          85       2
# 192          15.0          56        6.0   0.60%           0       2
# 195           6.0        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %%
players.market_value.loc[[31, 193, 196]]
# Out:
# 31     40.0
# 193    15.0
# 196     6.0
# Name: market_value, dtype: float64

# %%
players.fillna(method='bfill', axis=1).loc[[30, 192, 195]] # fills across columns
# Out:
#                   name            club age position position_cat market_value  \
# 30        Granit Xhaka         Arsenal  24        2            2         1815
# 192       Steve Mounie    Huddersfield  22       CF            1           56
# 195  Kasper Schmeichel  Leicester+City  30       GK            4         1601
#
#     page_views fpl_value fpl_sel fpl_points region  nationality new_foreign  \
# 30        1815       5.5   2.00%         85      2  Switzerland           0
# 192         56         6   0.60%          0      2        Benin           0
# 195       1601         5   2.40%        109      2      Denmark           0
#
#     age_cat club_id big_club new_signing
# 30        2       1        1           0
# 192       2       8        0           0
# 195       4       9        0           0

# %% [markdown]
# #### Skill Challenge

# %%
#From players dataframe, remove the label 2,10,21, &  market_value column. Assign the result to df2

# %%
df2 = players.drop(index=[2,10,21], columns='market_value')

# %%
df2.shape
# Out:
# (462, 16)

# %%
df2
# Out:
#                     name      club  age position  position_cat  page_views  \
# 0         Alexis Sanchez   Arsenal   28       LW             1        4329
# 1             Mesut Ozil   Arsenal   28       AM             1        4395
# 3           Theo Walcott   Arsenal   28       RW             1        2393
# 4      Laurent Koscielny   Arsenal   31       CB             3         912
# 5        Hector Bellerin   Arsenal   22       RB             3        1675
# ..                   ...       ...  ...      ...           ...         ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2         288
# 461       Arthur Masuaku  West+Ham   23       LB             3         199
# 462            Sam Byram  West+Ham   23       RB             3         198
# 463      Ashley Fletcher  West+Ham   21       CF             1         412
# 464         Diafra Sakho  West+Ham   27       CF             1         214
#
# ...

# %%
#Does the nationality column in df2 have anu NA value? How many unique nationalities are there?

# %%
df2.nationality[df2.nationality.isna()]
# Out:
# Series([], Name: nationality, dtype: object)

# %%
df2.nationality.isna().sum()
# Out:
# 0

# %%
df2.nationality.isna().isna().sum()
# Out:
# 0

# %%
np.count_nonzero(df2.nationality.isna())
# Out:
# 0

# %%
df2.nationality.unique()
# Out:
# array(['Chile', 'Germany', 'England', 'France', 'Spain', 'Nigeria',
#        'Switzerland', 'Wales', 'Brazil', 'Egypt', 'Argentina', 'Colombia',
#        'Bosnia', 'Norway', 'Poland', 'Scotland', 'Congo DR', 'Ireland',
#        'Netherlands', 'Australia', "Cote d'Ivoire", 'Finland', 'Cameroon',
#        'Austria', 'Israel', 'Czech Republic', 'Northern Ireland',
#        'Canada', 'Belgium', 'Iceland', 'Serbia', 'Portugal', 'Ghana',
#        'South Korea', 'Mali', 'Senegal', 'Curacao', 'Denmark', 'Slovenia',
#        'Trinidad and Tobago', 'Bermuda', 'Benin', 'Algeria', 'Jamaica',
#        'Japan', 'Tunisia', 'Croatia', 'Estonia', 'Ecuador', 'Armenia',
#        'Italy', 'Sweden', 'United States', 'Morocco', 'The Gambia',
#        'Kenya', 'Greece', 'Uruguay', 'Romania', 'Venezuela',
#        'New Zealand'], dtype=object)

# %%
df2.nationality.describe().loc['unique']
# Out:
# 61

# %%
df2.nationality.unique().size
# Out:
# 61

# %%
help(np.array)
# Out:
# Help on built-in function array in module numpy:
#
# array(...)
#     array(object, dtype=None, copy=True, order='K', subok=False, ndmin=0)
#
#     Create an array.
#
#     Parameters
#     ----------
#     object : array_like
#         An array, any object exposing the array interface, an object whose
#         __array__ method returns an array, or any (nested) sequence.
#     dtype : data-type, optional
#         The desired data-type for the array.  If not given, then the type will
#         be determined as the minimum type required to hold the objects in the
#         sequence.
#     copy : bool, optional
#         If true (default), then the object is copied.  Otherwise, a copy will
#         only be made if __array__ returns a copy, if obj is a nested sequence,
#         or if a copy is needed to satisfy any of the other requirements
#         (`dtype`, `order`, etc.).
#     order : {'K', 'A', 'C', 'F'}, optional
# ...

# %%
df2[['age', 'position']].nunique()
# Out:
# age         22
# position    13
# dtype: int64

# %%
df2[['age', 'position']].describe()
# Out:
#               age
# count  462.000000
# mean    26.777056
# std      3.939906
# min     17.000000
# 25%     24.000000
# 50%     27.000000
# 75%     29.000000
# max     38.000000

# %%
df2.set_index('club')
# Out:
#                          name  age position  position_cat  page_views  \
# club
# Arsenal        Alexis Sanchez   28       LW             1        4329
# Arsenal            Mesut Ozil   28       AM             1        4395
# Arsenal          Theo Walcott   28       RW             1        2393
# Arsenal     Laurent Koscielny   31       CB             3         912
# Arsenal       Hector Bellerin   22       RB             3        1675
# ...                       ...  ...      ...           ...         ...
# West+Ham  Edimilson Fernandes   21       CM             2         288
# West+Ham       Arthur Masuaku   23       LB             3         199
# West+Ham            Sam Byram   23       RB             3         198
# West+Ham      Ashley Fletcher   21       CF             1         412
# West+Ham         Diafra Sakho   27       CF             1         214
#
#           fpl_value fpl_sel  fpl_points  region  nationality  new_foreign  \
# club
# ...

# %%
players
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
#3.
df2.drop_duplicates(subset=['age', 'club', 'position'], keep='first').loc[:, ['age', 'position']]
# Out:
#      age position
# 0     28       LW
# 1     28       AM
# 3     28       RW
# 4     31       CB
# 5     22       RB
# ..   ...      ...
# 460   21       CM
# 461   23       LB
# 462   23       RB
# 463   21       CF
# 464   27       CF
#
# [433 rows x 2 columns]

# %% [markdown]
# #### 31st of july 2020

# %% [markdown]
# ##### Calculating aggregates with agg()

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
players.agg('mean')
# Out:
# age              26.776344
# position_cat      2.178495
# market_value     11.125649
# page_views      771.546237
# fpl_value         5.450538
# fpl_points       57.544086
# region            1.989247
# new_foreign       0.034409
# age_cat           3.195699
# club_id          10.253763
# big_club          0.309677
# new_signing       0.144086
# dtype: float64

# %%
players.fpl_value.mean()
# Out:
# 5.450537634408602

# %%
players.agg('min')
# Out:
# name            Aaron Cresswell
# club                    Arsenal
# age                          17
# position_cat                  1
# market_value               0.05
# page_views                    3
# fpl_value                     4
# fpl_sel                   0.00%
# fpl_points                    0
# region                        1
# nationality             Algeria
# new_foreign                   0
# age_cat                       1
# club_id                       1
# big_club                      0
# new_signing                   0
# dtype: object

# %%
players.agg(min)
# Out:
# name            Aaron Cresswell
# club                    Arsenal
# age                          17
# position_cat                  1
# market_value               0.05
# page_views                    3
# fpl_value                     4
# fpl_sel                   0.00%
# fpl_points                    0
# region                        1
# nationality             Algeria
# new_foreign                   0
# age_cat                       1
# club_id                       1
# big_club                      0
# new_signing                   0
# dtype: object

# %%
players.agg(np.min)
# Out:
# name            Aaron Cresswell
# club                    Arsenal
# age                          17
# position_cat                  1
# market_value               0.05
# page_views                    3
# fpl_value                     4
# fpl_sel                   0.00%
# fpl_points                    0
# region                        1
# nationality             Algeria
# new_foreign                   0
# age_cat                       1
# club_id                       1
# big_club                      0
# new_signing                   0
# dtype: object

# %%
'a'<'b'
# Out:
# True

# %%
ord('a')
# Out:
# 97

# %%
ord('d')
# Out:
# 100

# %%
ls = ['a', 'b', 'c', 'day']

# %%
min(ls)
# Out:
# 'a'

# %%
max(ls)
# Out:
# 'day'

# %%
players.agg('min')
# Out:
# name            Aaron Cresswell
# club                    Arsenal
# age                          17
# position_cat                  1
# market_value               0.05
# page_views                    3
# fpl_value                     4
# fpl_sel                   0.00%
# fpl_points                    0
# region                        1
# nationality             Algeria
# new_foreign                   0
# age_cat                       1
# club_id                       1
# big_club                      0
# new_signing                   0
# dtype: object

# %%
#OR
players.select_dtypes(np.number).agg('min')
# Out:
# age             17.00
# position_cat     1.00
# market_value     0.05
# page_views       3.00
# fpl_value        4.00
# fpl_points       0.00
# region           1.00
# new_foreign      0.00
# age_cat          1.00
# club_id          1.00
# big_club         0.00
# new_signing      0.00
# dtype: float64

# %%
import sys
sys.version
# Out:
# '3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)]'

# %%
players.select_dtypes(np.number).agg([min, max, 'mean'])
# Out:
#             age  position_cat  market_value   page_views  fpl_value  \
# min   17.000000      1.000000      0.050000     3.000000   4.000000
# max   38.000000      4.000000     75.000000  7664.000000  12.500000
# mean  26.776344      2.178495     11.125649   771.546237   5.450538
#
#       fpl_points    region  new_foreign   age_cat    club_id  big_club  \
# min     0.000000  1.000000     0.000000  1.000000   1.000000  0.000000
# max   264.000000  4.000000     1.000000  6.000000  20.000000  1.000000
# mean   57.544086  1.989247     0.034409  3.195699  10.253763  0.309677
#
#       new_signing
# min      0.000000
# max      1.000000
# mean     0.144086

# %% [markdown]
# #### Some-Shape Transform

# %%
players.head(3)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1      Mesut Ozil  Arsenal   28       AM             1          50.0
# 2       Petr Cech  Arsenal   35       GK             4           7.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0

# %%
#fx rate = 1.02% per year for banks

# %%
#usdeur = 0.91

# %%
players.loc[:, ['market_value', 'fpl_value']]
# Out:
#      market_value  fpl_value
# 0            65.0       12.0
# 1            50.0        9.5
# 2             7.0        5.5
# 3            20.0        7.5
# 4            22.0        6.0
# ..            ...        ...
# 460           5.0        4.5
# 461           7.0        4.5
# 462           4.5        4.5
# 463           1.0        4.5
# 464          10.0        5.5
#
# [465 rows x 2 columns]

# %%
players.loc[:, ['market_value', 'fpl_value']].transform(lambda x: x * 0.91)
# Out:
#      market_value  fpl_value
# 0          59.150     10.920
# 1          45.500      8.645
# 2           6.370      5.005
# 3          18.200      6.825
# 4          20.020      5.460
# ..            ...        ...
# 460         4.550      4.095
# 461         6.370      4.095
# 462         4.095      4.095
# 463         0.910      4.095
# 464         9.100      5.005
#
# [465 rows x 2 columns]

# %%
#ASIDE

# %%
#choice

# %%
from random import choice

# %%
names = ['bread', 'john', 'sam', 'mike']

# %%
choice(names)
# Out:
# 'bread'

# %%
#string methods -> .str.

# %%
'ad'.upper()
# Out:
# 'AD'

# %%
ser = pd.Series(names)

# %%
ser
# Out:
# 0    bread
# 1     john
# 2      sam
# 3     mike
# dtype: object

# %%
#ser.upper() - this will give an error

# %%
ser.str.upper()
# Out:
# 0    BREAD
# 1     JOHN
# 2      SAM
# 3     MIKE
# dtype: object

# %%
ser.str.lower()
# Out:
# 0    bread
# 1     john
# 2      sam
# 3     mike
# dtype: object

# %%
ser.str.title()
# Out:
# 0    Bread
# 1     John
# 2      Sam
# 3     Mike
# dtype: object

# %%
ser.str.swapcase()
# Out:
# 0    BREAD
# 1     JOHN
# 2      SAM
# 3     MIKE
# dtype: object

# %%
#Creating a function that should:
#-apply a random string capitalization
#-to a sequence of values
#-return the transformed sequence
from random import choice

# %%
def random_case(x):
    funcs=[x.str.swapcase(), x.str.lower(), x.str.upper(), x.str.title()]
    return choice(funcs)
players.select_dtypes(include=object).transform(random_case)
# Out:
#                     name      club position fpl_sel     nationality
# 0         alexis sanchez   arsenal       Lw  17.10%           CHILE
# 1             mesut ozil   arsenal       Am   5.60%         GERMANY
# 2              petr cech   arsenal       Gk   5.90%  CZECH REPUBLIC
# 3           theo walcott   arsenal       Rw   1.50%         ENGLAND
# 4      laurent koscielny   arsenal       Cb   0.70%          FRANCE
# ..                   ...       ...      ...     ...             ...
# 460  edimilson fernandes  west+ham       Cm   0.40%     SWITZERLAND
# 461       arthur masuaku  west+ham       Lb   0.20%        CONGO DR
# 462            sam byram  west+ham       Rb   0.30%         ENGLAND
# 463      ashley fletcher  west+ham       Cf   5.90%         ENGLAND
# 464         diafra sakho  west+ham       Cf   0.10%         SENEGAL
#
# [465 rows x 5 columns]

# %%
for i in range(4):
    print(players.select_dtypes(include=object).transform(random_case))
# Out:
#                     name      club position fpl_sel     nationality
# 0         alexis sanchez   Arsenal       LW  17.10%           Chile
# 1             mesut ozil   Arsenal       AM   5.60%         Germany
# 2              petr cech   Arsenal       GK   5.90%  Czech Republic
# 3           theo walcott   Arsenal       RW   1.50%         England
# 4      laurent koscielny   Arsenal       CB   0.70%          France
# ..                   ...       ...      ...     ...             ...
# 460  edimilson fernandes  West+Ham       CM   0.40%     Switzerland
# 461       arthur masuaku  West+Ham       LB   0.20%        Congo Dr
# 462            sam byram  West+Ham       RB   0.30%         England
# 463      ashley fletcher  West+Ham       CF   5.90%         England
# 464         diafra sakho  West+Ham       CF   0.10%         Senegal
#
# [465 rows x 5 columns]
#                     name      club position fpl_sel     nationality
# ...

# %% [markdown]
# ##### More Flexibility with apply()

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
def round_floats(x):
    if x.dtype == np.float64:
        return round(x)
    return x
players.apply(round_floats)
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.0
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
players.market_value.dtype, players.fpl_value.dtype
# Out:
# (dtype('float64'), dtype('float64'))

# %%
def round_floats(x):
    if x.dtype == np.float64:
        return round(x)
    return x
players.transform(round_floats)
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.0
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
players.select_dtypes(np.float64).head()
# Out:
#    market_value  fpl_value
# 0          65.0       12.0
# 1          50.0        9.5
# 2           7.0        5.5
# 3          20.0        7.5
# 4          22.0        6.0

# %%
players.select_dtypes(np.int64)
# Out:
#      age  position_cat  page_views  fpl_points  region  new_foreign  age_cat  \
# 0     28             1        4329         264       3            0        4
# 1     28             1        4395         167       2            0        4
# 2     35             4        1529         134       2            0        6
# 3     28             1        2393         122       1            0        4
# 4     31             3         912         121       2            0        4
# ..   ...           ...         ...         ...     ...          ...      ...
# 460   21             2         288          38       2            0        1
# 461   23             3         199          34       4            0        2
# 462   23             3         198          29       1            0        2
# 463   21             1         412          16       1            0        1
# 464   27             1         214          12       4            0        3
#
#      club_id  big_club  new_signing
# ...

# %%
players.select_dtypes(np.float64).apply(round_floats).head()
# Out:
#    market_value  fpl_value
# 0          65.0       12.0
# 1          50.0       10.0
# 2           7.0        6.0
# 3          20.0        8.0
# 4          22.0        6.0

# %%
#apply = agg() + transform()

# %%
# apply as aggregates

# %%
players.agg('mean')
# Out:
# age              26.776344
# position_cat      2.178495
# market_value     11.125649
# page_views      771.546237
# fpl_value         5.450538
# fpl_points       57.544086
# region            1.989247
# new_foreign       0.034409
# age_cat           3.195699
# club_id          10.253763
# big_club          0.309677
# new_signing       0.144086
# dtype: float64

# %%
players.apply('mean')
# Out:
# age              26.776344
# position_cat      2.178495
# market_value     11.125649
# page_views      771.546237
# fpl_value         5.450538
# fpl_points       57.544086
# region            1.989247
# new_foreign       0.034409
# age_cat           3.195699
# club_id          10.253763
# big_club          0.309677
# new_signing       0.144086
# dtype: float64

# %%
#flipping the axis parameter

# %%
players.apply('mean', axis=1)
# Out:
# 0      392.333333
# 1      388.208333
# 2      143.708333
# 3      214.875000
# 4       91.916667
#           ...
# 460     31.875000
# 461     24.791667
# 462     23.750000
# 463     39.875000
# 464     24.708333
# Length: 465, dtype: float64

# %%
players.apply('mean', axis=0)
# Out:
# age              26.776344
# position_cat      2.178495
# market_value     11.125649
# page_views      771.546237
# fpl_value         5.450538
# fpl_points       57.544086
# region            1.989247
# new_foreign       0.034409
# age_cat           3.195699
# club_id          10.253763
# big_club          0.309677
# new_signing       0.144086
# dtype: float64

# %%
players.loc[460,:]
# Out:
# name            Edimilson Fernandes
# club                       West+Ham
# age                              21
# position                         CM
# position_cat                      2
# market_value                      5
# page_views                      288
# fpl_value                       4.5
# fpl_sel                       0.40%
# fpl_points                       38
# region                            2
# nationality             Switzerland
# new_foreign                       0
# age_cat                           1
# club_id                          20
# big_club                          0
# new_signing                       1
# Name: 460, dtype: object

# %%
players.loc[460, [dtype != object for dtype in players.dtypes]]
# Out:
# age              21
# position_cat      2
# market_value      5
# page_views      288
# fpl_value       4.5
# fpl_points       38
# region            2
# new_foreign       0
# age_cat           1
# club_id          20
# big_club          0
# new_signing       1
# Name: 460, dtype: object

# %%
players.dtypes
# Out:
# name             object
# club             object
# age               int64
# position         object
# position_cat      int64
# market_value    float64
# page_views        int64
# fpl_value       float64
# fpl_sel          object
# fpl_points        int64
# region            int64
# nationality      object
# new_foreign       int64
# age_cat           int64
# club_id           int64
# big_club          int64
# new_signing       int64
# dtype: object

# %%
players.loc[460, [dtypes != object for dtypes in players.dtypes]].mean()
# Out:
# 31.875

# %% [markdown]
# #### Element-wise Operations with applymap()

# %%
#vectorized ops: apply(), transform(), agg()

# %%
#non-vectorized ops: applymap()

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
inflation = 1.02

# %%
mini_df = players.loc[:, ['market_value', 'fpl_value']]

# %%
mini_df * inflation
# Out:
#      market_value  fpl_value
# 0           66.30      12.24
# 1           51.00       9.69
# 2            7.14       5.61
# 3           20.40       7.65
# 4           22.44       6.12
# ..            ...        ...
# 460          5.10       4.59
# 461          7.14       4.59
# 462          4.59       4.59
# 463          1.02       4.59
# 464         10.20       5.61
#
# [465 rows x 2 columns]

# %%
#OR
players.loc[:, ['market_value', 'fpl_value']] * inflation
# Out:
#      market_value  fpl_value
# 0           66.30      12.24
# 1           51.00       9.69
# 2            7.14       5.61
# 3           20.40       7.65
# 4           22.44       6.12
# ..            ...        ...
# 460          5.10       4.59
# 461          7.14       4.59
# 462          4.59       4.59
# 463          1.02       4.59
# 464         10.20       5.61
#
# [465 rows x 2 columns]

# %%
from datetime import datetime

# %%
counter = 0 
def log_and_transform(x):
    global counter
    counter += 1
    if counter % 100 == 0:
        print(f"It's{datetime.now()} i just adjusted the {counter}th value")
    return x*inflation

# %%
mini_df.applymap(log_and_transform)
# Out:
# It's2021-01-30 01:30:21.522098 i just adjusted the 100th value
# It's2021-01-30 01:30:21.522098 i just adjusted the 200th value
# It's2021-01-30 01:30:21.530093 i just adjusted the 300th value
# It's2021-01-30 01:30:21.530093 i just adjusted the 400th value
# It's2021-01-30 01:30:21.530093 i just adjusted the 500th value
# It's2021-01-30 01:30:21.530093 i just adjusted the 600th value
# It's2021-01-30 01:30:21.538096 i just adjusted the 700th value
# It's2021-01-30 01:30:21.538096 i just adjusted the 800th value
# It's2021-01-30 01:30:21.538096 i just adjusted the 900th value
# It's2021-01-30 01:30:21.546098 i just adjusted the 1000th value
# It's2021-01-30 01:30:21.546098 i just adjusted the 1100th value
# It's2021-01-30 01:30:21.546098 i just adjusted the 1200th value
# It's2021-01-30 01:30:21.546098 i just adjusted the 1300th value
#      market_value  fpl_value
# 0           66.30      12.24
# 1           51.00       9.69
# 2            7.14       5.61
# ...

# %% [markdown]
# #### 31st july continued....

# %% [markdown]
# #### Skill Challenge

# %%
#Create a standalone function

# %%
df = players.loc[3:10, ['page_views', 'market_value']]

# %%
type( players.loc[3:10, ['page_views', 'market_value']])
# Out:
# pandas.core.frame.DataFrame

# %%
def popularity(x):
    
    if x < 220:
        return "'relatively unknown'"
    elif x < 600:
        return "'kind of popular'"
    elif x <2000:
        return "'popular'"
    else:
        return "'super popular'"

# %%
players['popularity']=players.page_views.apply(popularity)

# %%
players.popularity
# Out:
# 0           'super popular'
# 1           'super popular'
# 2                 'popular'
# 3           'super popular'
# 4                 'popular'
#                ...
# 460       'kind of popular'
# 461    'relatively unknown'
# 462    'relatively unknown'
# 463       'kind of popular'
# 464    'relatively unknown'
# Name: popularity, Length: 465, dtype: object

# %%
players.popularity.value_counts().loc["'super popular'"]
# Out:
# 37

# %%
players[players.popularity=="'super popular'"]
# Out:
#                       name               club  age position  position_cat  \
# 0           Alexis Sanchez            Arsenal   28       LW             1
# 1               Mesut Ozil            Arsenal   28       AM             1
# 3             Theo Walcott            Arsenal   28       RW             1
# 6           Olivier Giroud            Arsenal   30       CF             1
# 24             Lucas Perez            Arsenal   28       CF             1
# 33           Jermain Defoe        Bournemouth   34       CF             1
# 96             Eden Hazard            Chelsea   26       LW             1
# 97             Diego Costa            Chelsea   28       CF             1
# 99   Marcos Alonso Mendoza            Chelsea   26       LB             3
# 103             David Luiz            Chelsea   30       CB             3
# 104          Cesc Fabregas            Chelsea   30       CM             2
# 106           Victor Moses            Chelsea   26       RM             2
# ...

# %%
players[players.popularity=="'super popular'"].shape
# Out:
# (37, 18)

# %% [markdown]
# ##### Setting DataFrame Values

# %%
players.head(10)
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
# 5    Hector Bellerin  Arsenal   22       RB             3          30.0
# 6     Olivier Giroud  Arsenal   30       CF             1          22.0
# 7      Nacho Monreal  Arsenal   31       LB             3          13.0
# 8   Shkodran Mustafi  Arsenal   25       CB             3          30.0
# 9         Alex Iwobi  Arsenal   21       LW             1          10.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# ...

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing       popularity
# ...

# %%
players.loc[3, 'position'] = 'CM'

# %%
players.iloc[3,3] = 'RW'

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing       popularity
# ...

# %%
#at and iat[] should be preferred for single value assignment

# %%
players.at[3,'position'] = 'CM'

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       CM             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing       popularity
# ...

# %%
players.iat[3,3] = 'RW'

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing       popularity
# ...

# %%
# %timeit players.at[2, 'position'] = 'CM'
# Out:
# 26.7 µs ± 2.98 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit players.iat[3, 3] = 'CM'
# Out:
# 26.3 µs ± 1.48 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit players.loc[2, 'position'] = 'CM'
# Out:
# 1.18 ms ± 140 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ##### View Vs Copy

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       CM             4           7.0
# 3       Theo Walcott  Arsenal   28       CM             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing       popularity
# ...

# %%
players.loc[0:3, 'position'] = ['CM', 'RW', 'CB', 'GK']

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       CM             1          65.0
# 1         Mesut Ozil  Arsenal   28       RW             1          50.0
# 2          Petr Cech  Arsenal   35       CB             4           7.0
# 3       Theo Walcott  Arsenal   28       GK             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing       popularity
# ...

# %%
#Aaron -> nickname

# %%
players.loc[players.name.str.startswith('Aaron')]
# Out:
#                 name          club  age position  position_cat  market_value  \
# 15      Aaron Ramsey       Arsenal   26       CM             2          35.0
# 157     Aaron Lennon       Everton   30       RW             1           5.0
# 176       Aaron Mooy  Huddersfield   26       CM             2           5.0
# 455  Aaron Cresswell      West+Ham   27       LB             3          12.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 15         1040        7.0   5.10%          56       1       Wales
# 157         504        5.5   0.20%          22       1     England
# 176         588        5.5   2.50%           0       4   Australia
# 455         380        5.0   1.30%          60       1     England
#
#      new_foreign  age_cat  club_id  big_club  new_signing         popularity
# 15             0        3        1         1            0          'popular'
# 157            0        4        7         0            0  'kind of popular'
# ...

# %%
players.set_index('name').filter(regex='(?i)Aaron', axis=0)
# Out:
#                              club  age position  position_cat  market_value  \
# name
# Aaron Ramsey              Arsenal   26       CM             2         35.00
# Aaron Lennon              Everton   30       RW             1          5.00
# Aaron Mooy           Huddersfield   26       CM             2          5.00
# Rolando Aarons   Newcastle+United   21       LW             1          0.75
# Aaron Cresswell          West+Ham   27       LB             3         12.00
#
#                  page_views  fpl_value fpl_sel  fpl_points  region  \
# name
# Aaron Ramsey           1040        7.0   5.10%          56       1
# Aaron Lennon            504        5.5   0.20%          22       1
# Aaron Mooy              588        5.5   2.50%           0       4
# Rolando Aarons          170        4.5   0.10%           0       1
# Aaron Cresswell         380        5.0   1.30%          60       1
#
#                 nationality  new_foreign  age_cat  club_id  big_club  \
# name
# ...

# %%
players.loc[players.name.str.startswith('Aaron'),'name'] = 'Ronny'

# %%
players.loc[[15,157,176,455]]
# Out:
#       name          club  age position  position_cat  market_value  \
# 15   Ronny       Arsenal   26       CM             2          35.0
# 157  Ronny       Everton   30       RW             1           5.0
# 176  Ronny  Huddersfield   26       CM             2           5.0
# 455  Ronny      West+Ham   27       LB             3          12.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 15         1040        7.0   5.10%          56       1       Wales
# 157         504        5.5   0.20%          22       1     England
# 176         588        5.5   2.50%           0       4   Australia
# 455         380        5.0   1.30%          60       1     England
#
#      new_foreign  age_cat  club_id  big_club  new_signing         popularity
# 15             0        3        1         1            0          'popular'
# 157            0        4        7         0            0  'kind of popular'
# ...

# %% [markdown]
# #### Adding DataFrame Cols

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       CM             1          65.0
# 1         Mesut Ozil  Arsenal   28       RW             1          50.0
# 2          Petr Cech  Arsenal   35       CB             4           7.0
# 3       Theo Walcott  Arsenal   28       GK             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing       popularity
# ...

# %%
players.popularity
# Out:
# 0           'super popular'
# 1           'super popular'
# 2                 'popular'
# 3           'super popular'
# 4                 'popular'
#                ...
# 460       'kind of popular'
# 461    'relatively unknown'
# 462    'relatively unknown'
# 463       'kind of popular'
# 464    'relatively unknown'
# Name: popularity, Length: 465, dtype: object

# %%
'MVtoFPL' in players
# Out:
# False

# %%
'name' in players
# Out:
# True

# %%
players['MVtoFPL'] = 1.0

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       CM             1          65.0
# 1         Mesut Ozil  Arsenal   28       RW             1          50.0
# 2          Petr Cech  Arsenal   35       CB             4           7.0
# 3       Theo Walcott  Arsenal   28       GK             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing       popularity  \
# ...

# %%
players['MVtoFPL'] = players['market_value']/players['fpl_value']

# %%
players
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       CM             1          65.0
# 1             Mesut Ozil   Arsenal   28       RW             1          50.0
# 2              Petr Cech   Arsenal   35       CB             4           7.0
# 3           Theo Walcott   Arsenal   28       GK             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       CM             1          65.0
# 1         Mesut Ozil  Arsenal   28       RW             1          50.0
# 2          Petr Cech  Arsenal   35       CB             4           7.0
# 3       Theo Walcott  Arsenal   28       GK             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing       popularity  \
# ...

# %%
df_mini = players.iloc[:4, 1:5]

# %%
df_mini
# Out:
#       club  age position  position_cat
# 0  Arsenal   28       CM             1
# 1  Arsenal   28       RW             1
# 2  Arsenal   35       CB             4
# 3  Arsenal   28       GK             1

# %%
player_names = pd.Series(['Brandon', 'Bradley', 'Ronald', 'Ronny'])

# %%
player_names
# Out:
# 0    Brandon
# 1    Bradley
# 2     Ronald
# 3      Ronny
# dtype: object

# %%
df_mini
# Out:
#       club  age position  position_cat
# 0  Arsenal   28       CM             1
# 1  Arsenal   28       RW             1
# 2  Arsenal   35       CB             4
# 3  Arsenal   28       GK             1

# %%
df_mini.insert(0, 'nickname', player_names)

# %%
df_mini
# Out:
#   nickname     club  age position  position_cat
# 0  Brandon  Arsenal   28       CM             1
# 1  Bradley  Arsenal   28       RW             1
# 2   Ronald  Arsenal   35       CB             4
# 3    Ronny  Arsenal   28       GK             1

# %%
#the assign approach -> this allows to add

# %%
df_mini.assign(career_goals=[12,67,179,49])
# Out:
#   nickname     club  age position  position_cat  career_goals
# 0  Brandon  Arsenal   28       CM             1            12
# 1  Bradley  Arsenal   28       RW             1            67
# 2   Ronald  Arsenal   35       CB             4           179
# 3    Ronny  Arsenal   28       GK             1            49

# %% [markdown]
# #### Adding Rows to DataFrame

# %%
df_mini
# Out:
#   nickname     club  age position  position_cat
# 0  Brandon  Arsenal   28       CM             1
# 1  Bradley  Arsenal   28       RW             1
# 2   Ronald  Arsenal   35       CB             4
# 3    Ronny  Arsenal   28       GK             1

# %%
# the append approach() method -> series, dfs, or a collection of them

# %%
cristiano = pd.Series({
               'nickname' : 'cristiano',
               'age' : 32,
               'position' : 'RW',
               'club' : 'Juventus',
               'position_cat' : 1
               }, name=4)

# %%
cristiano
# Out:
# nickname        cristiano
# age                    32
# position               RW
# club             Juventus
# position_cat            1
# Name: 4, dtype: object

# %%
df_mini.append(cristiano)
# Out:
#     nickname      club  age position  position_cat
# 0    Brandon   Arsenal   28       CM             1
# 1    Bradley   Arsenal   28       RW             1
# 2     Ronald   Arsenal   35       CB             4
# 3      Ronny   Arsenal   28       GK             1
# 4  cristiano  Juventus   32       RW             1

# %%
other_players = pd.DataFrame({
                       'nicknames' : ['Gianluigi','lionel'],
                       'age' : [37,32],
                       'club' : ['Juventsu', 'Barcelona'],
                       'position' : ['GK', 'CF'],
                       'position_cat' : [4,2]
                   }, index=[5,6])

# %%
df_mini.append(other_players)
# Out:
#   nickname       club  age position  position_cat  nicknames
# 0  Brandon    Arsenal   28       CM             1        NaN
# 1  Bradley    Arsenal   28       RW             1        NaN
# 2   Ronald    Arsenal   35       CB             4        NaN
# 3    Ronny    Arsenal   28       GK             1        NaN
# 5      NaN   Juventsu   37       GK             4  Gianluigi
# 6      NaN  Barcelona   32       CF             2     lionel

# %%
df_mini = df_mini.append(other_players)

# %%
df_mini.loc[9] = 'some row value'

# %%
#adding rows to DFs is inefficient(very expensive)

# %% [markdown]
# #### Skill Challenge

# %% [markdown]
# #### 1. From the players dataframe, select 4 columns and 4 rows of no particular order. Assign the resulting dataframe to df_random.

# %%
df_random = players.sample(4, axis=0).sample(4, axis=1)

# %%
df_random
# Out:
#     nationality  position_cat position fpl_sel
# 47      England             2       CM   1.10%
# 293     England             3       CB   3.60%
# 28      Germany             3       CB   1.00%
# 121       Wales             4       GK   2.10%

# %%
df_random.shape
# Out:
# (4, 4)

# %% [markdown]
# #### 2. Extend df_random1)vertically by adding a new row , and 2)horizontally by adding a new column.Do this as two seperate operations.

# %%
un = pd.Series({
       'nationality' : 'Nigerian', 
       'age' : 32,
       'market_value' : 20, 
       'popularity' : 'popular'
}, name=412)

# %%
df_random = df_random.append(un, ) #1. adding the row to the dataframe

# %%
df_random.shape
# Out:
# (5, 7)

# %%
df_random
# Out:
#     nationality  position_cat position fpl_sel   age  market_value popularity
# 47      England           2.0       CM   1.10%   NaN           NaN        NaN
# 293     England           3.0       CB   3.60%   NaN           NaN        NaN
# 28      Germany           3.0       CB   1.00%   NaN           NaN        NaN
# 121       Wales           4.0       GK   2.10%   NaN           NaN        NaN
# 412    Nigerian           NaN      NaN     NaN  32.0          20.0    popular

# %%
fav_food = ['rice', 'beans', 'yam', 'bread', 'cassava']

# %%
df_random = df_random.assign(fav_food = fav_food)# 2. adding a new column to the dataframe

# %%
# %timeit df_random.assign(fav_food = fav_food)
# %timeit df_random.append(un)
# Out:
# 860 µs ± 14 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 16.3 ms ± 91.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# Adding a column to a dataframe is faster compared to adding a row : approximately 16.5 times faster
